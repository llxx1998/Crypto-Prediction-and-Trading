# %% [markdown]
# # tweepy

# %%
import tweepy as tw
import pandas as pd

# %%
api_key = "jCbSX23Iy1Tr4qjsHHKODrPX7"
api_key_secret = "OhwrY46w0Mxhd5JNde4S6ARawzg5FjhWUq6fH3Ibr5PiaRQHzo"
access_key = "1455590686548537348-rAwmBkBvlfW9I9qHHIyC5WP9bvZD8R"
access_key_secret = "vFgMCFWQKXLdSiQuK7akFT1RPIx5D6FRdijEkCbJv0HcK"

# %%
auth = tw.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_key, access_key_secret)

api = tw.API(auth, wait_on_rate_limit=True)
search_query = "#bitcoin"

# %%
# %%time
# get tweets from the API
tweets = tw.Cursor(api.search_tweets,
              q=search_query,
              lang="en").items(100)

# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
tweets_df = pd.DataFrame()
# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)
    
tweets_df
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# CPU times: user 4.88 s, sys: 407 ms, total: 5.29 s
# Wall time: 22.2 s
#                                          user_name  \
# 0                                       Mark Wally
# 1                                BNB Price Tracker
# 2                             Hyrra❤️free tag 🍀🎹⚡🌌
# 3                                          known't
# 4   khmerxbxboi "HashTag Tester" (STOCK-GOD) 🇺🇸 🇰🇭
# ..                                             ...
# 95  khmerxbxboi "HashTag Tester" (STOCK-GOD) 🇺🇸 🇰🇭
# 96                                  Robi Chatterji
# 97    Dr Recursion $QUARTZ $CPOOL $SPA $XCAD $COTI
# 98                             MainStreet₿itcoin 👑
# 99                                          kenyaa
#
#                  user_location  \
# 0              Beautiful World
# 1
# 2
# 3
# 4   Aesthetics of Calculations
# ..                         ...
# 95  Aesthetics of Calculations
# 96
# 97
# 98     21 Bitcoin Avenue, Mars
# 99               United States
#
#                                      user_description  user_verified  \
# 0                               Proud Canadian 🇨🇦❤️🇨🇦          False
# 1              #BNB #BNBTracker #BinanceCoin #Binance          False
# 2   there's a rainbow after the rain \nusn baru da...          False
# 3                                 i do not comprehend          False
# 4   CLICK ON YOUTUBE FOR Stocks POWER !  https://t...          False
# ..                                                ...            ...
# 95  CLICK ON YOUTUBE FOR Stocks POWER !  https://t...          False
# 96                                                             False
# 97  Software Engineer, Crypto Trader, SSI Advocate...          False
# 98  Learn from the past, create the present, contr...          False
# 99  Actor | Model | Writer | Singer | Trader #Bitc...          False
#
#                         date  \
# 0  2022-09-25 01:52:25+00:00
# 1  2022-09-25 01:52:24+00:00
# 2  2022-09-25 01:52:23+00:00
# 3  2022-09-25 01:52:21+00:00
# 4  2022-09-25 01:52:20+00:00
# ..                       ...
# 95 2022-09-25 01:49:30+00:00
# 96 2022-09-25 01:49:28+00:00
# 97 2022-09-25 01:49:27+00:00
# 98 2022-09-25 01:49:25+00:00
# 99 2022-09-25 01:49:23+00:00
#
#                                                  text  \
# 0   RT @RoseXrp: Financial markets will see a melt...
# 1   #BinanceCoin price update: $BNB\n\n#BNB $275.4...
# 2   RT @TKralow: REMINDER: I am giving away $1,000...
# 3   RT @WatcherGuru: FUN FACT: 🇭🇺 Hungary is the h...
# 4   NEXT WEEK = $ENVX = like if you BULLISH !\n#st...
# ..                                                ...
# 95  NEXT WEEK = $CRTD = like if you BULLISH !\n#st...
# 96  RT @BitcoinMagazine: 🇿🇦 South Africans receivi...
# 97  RT @milesdeutscher: You can’t apply data from ...
# 98  RT @Excellion: Everyone on the planet that req...
# 99  RT @TKralow: REMINDER: I am giving away $1,000...
#
#                                              hashtags               source
# 0                                                None  Twitter for Android
# 1   [BinanceCoin, BNB, Bitcoin, Ethereum, altcoin,...      Twitter Web App
# 2                                           [Bitcoin]  Twitter for Android
# 3                                           [Bitcoin]      Twitter Web App
# 4   [stockmarkets, IranianLivesMatter, bb24, Debat...      Twitter Web App
# ..                                                ...                  ...
# 95  [stockmarkets, IranianLivesMatter, bb24, Debat...      Twitter Web App
# 96                                          [bitcoin]  Twitter for Android
# 97                                          [Bitcoin]   Twitter for iPhone
# 98                                          [Bitcoin]   Twitter for iPhone
# 99                                          [Bitcoin]           pennykenya
#
# [100 rows x 8 columns]

# %% [markdown]
# # twitterSearchScraper

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
maxTweets = 1000000
# Creating list to append tweet data to
tweets_list = []
# Using TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('bitcoin since:2020-09-27 until:2022-09-27 near:London radius:15km').get_items()):
    if i > maxTweets:
        break
    tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.username])
    
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df
# Out:
# Empty DataFrame
# Columns: [Datetime, Tweet Id, Text, Username]
# Index: []

# %%
tweets_df = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df
# Out:
#                        Datetime             Tweet Id  \
# 0     2022-09-26 23:59:58+00:00  1574549371298799616
# 1     2022-09-26 23:59:57+00:00  1574549366383120384
# 2     2022-09-26 23:59:52+00:00  1574549344963133440
# 3     2022-09-26 23:59:51+00:00  1574549341808652288
# 4     2022-09-26 23:59:50+00:00  1574549339313033216
# ...                         ...                  ...
# 15584 2022-09-26 17:01:02+00:00  1574443941738561536
# 15585 2022-09-26 17:01:00+00:00  1574443933983293440
# 15586 2022-09-26 17:00:59+00:00  1574443931651260425
# 15587 2022-09-26 17:00:59+00:00  1574443930938384384
# 15588 2022-09-26 17:00:57+00:00  1574443924260671489
#
#                                                     Text         Username
# 0      Current #Cardano price Alert: \n\n#ADA $0.4473...   CardanoTracker
# 1      3 reasons why Bitcoin is regaining its crypto ...  meiling13316644
# 2      Bitcoin price index https://t.co/o7UcHJUPrE #U...   WorldCoinIndex
# 3      @Vespene_Energy is financing the build-out of ...       merissa_co
# 4      but in bitcoin we say don't trust, verify. \n\...       merissa_co
# ...                                                  ...              ...
# 15584  [1h] #Bitcoin market is weakly trending down c...        BitSwings
# 15585  How #ArtificialIntelligence will reshape our l...     VeilleCyber3
# 15586  Owning #Bitcoin is opening a short to the fiat...     Zenon_Citium
# 15587  MartyK found #bitcoin in a Blue vault at this ...         168_ETim
# 15588  @kdrpkmzc1 @eyupyildiz Zaten aklı fikri borsad...      OLCAYDEMIR2
#
# [15589 rows x 4 columns]
